# %%
#from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://vnexpress.net/'

# %%
hdr = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Mobile Safari/537.36 Edg/116.0.1938.54'}
response = requests.get(url, headers=hdr)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Báo VnExpress - Báo tiếng Việt nhiều người xem nhất</title><meta content="VnExpress tin tức mới nhất - Thông tin nhanh &amp; chính xác được cập nhật hàng giờ. Đọc báo tin tức online Việt Nam &amp; Thế giới nóng nhất trong ngày về thể thao, thời sự, pháp luật, kinh doanh,..." name="description"/>
# <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="keywords"/>
# <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="news_keywords"/>
# <meta charset="utf-8"/>
# <meta content="#A0234F" name="theme-color">
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=yes" name="viewport"/>
# <meta content="IE=100" http-equiv="X-UA-Compatible">
# <meta content="1547540628876392" property="fb:app_id"/>
# <meta content="1800" http-equiv="REFRESH"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Báo VnExpress - Báo tiếng Việt nhiều người xem nhất
#   </title>
#   <meta content="VnExpress tin tức mới nhất - Thông tin nhanh &amp; chính xác được cập nhật hàng giờ. Đọc báo tin tức online Việt Nam &amp; Thế giới nóng nhất trong ngày về thể thao, thời sự, pháp luật, kinh doanh,..." name="description"/>
#   <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="keywords"/>
#   <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="news_keywords"/>
#   <meta charset="utf-8"/>
#   <meta content="#A0234F" name="theme-color">
#    <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=yes" name="viewport"/>
#    <meta content="IE=100" http-equiv="X-UA-Compatible">
#     <meta content="1547540628876392" property="fb:app_id"/>
# ...

# %%
tags = soup.findAll("div", {"class": "md"})
tags
# Out:
# []

# %%
for mytag in tags:
  print(mytag.get_text())

# %%
data = requests.get(url).text
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# /
# /
# /tin-tuc-24h
# /thoi-su
# /goc-nhin
# /the-gioi
# https://video.vnexpress.net/
# /podcast
# /kinh-doanh
# /bat-dong-san
# /khoa-hoc
# /giai-tri
# /the-thao
# /phap-luat
# /giao-duc
# /suc-khoe
# /doi-song
# /du-lich
# /so-hoa
# /oto-xe-may
# /y-kien
# /tam-su
# /thu-gian
# https://vnexpress.net/ong-nguyen-van-the-bi-de-nghi-ky-luat-4815713.html
# https://vnexpress.net/ong-nguyen-van-the-bi-de-nghi-ky-luat-4815713.html
# https://vnexpress.net/ong-nguyen-van-the-bi-de-nghi-ky-luat-4815713.html
# https://vnexpress.net/ong-nguyen-van-the-bi-de-nghi-ky-luat-4815713.html#box_comment
# https://vnexpress.net/temu-gioi-han-don-hang-khong-qua-mot-trieu-dong-4815594.html
# https://vnexpress.net/temu-gioi-han-don-hang-khong-qua-mot-trieu-dong-4815594.html
# https://vnexpress.net/temu-gioi-han-don-hang-khong-qua-mot-trieu-dong-4815594.html#box_comment
# https://vnexpress.net/temu-gioi-han-don-hang-khong-qua-mot-trieu-dong-4815594.html
# ...

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>
print(table)
# Out:
# None

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="VnExpress - Bao tieng Viet nhieu nguoi xem nhat" src="https://s1.vnecdn.net/vnexpress/restruct/i/v9525/mobile_redesign/graphics/logo-vnexpress.svg"/>
# https://s1.vnecdn.net/vnexpress/restruct/i/v9525/mobile_redesign/graphics/logo-vnexpress.svg
# <img alt="Ông Nguyễn Văn Thể bị đề nghị kỷ luật" class="vne_lazy_image" data-original="https://i1-vnexpress.vnecdn.net/2024/11/13/1851-1666317611-1731493112-7517-1731493155.jpg?w=500&amp;h=300&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=uRZZ209RSPd8lEcwnmWYvw" data-original-2x="https://i1-vnexpress.vnecdn.net/2024/11/13/1851-1666317611-1731493112-7517-1731493155.jpg?w=500&amp;h=300&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=nax6B_1vnSEYEk-gszw1EQ" data-original-video="" src="https://i1-vnexpress.vnecdn.net/2024/11/13/1851-1666317611-1731493112-7517-1731493155.jpg?w=500&amp;h=300&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=uRZZ209RSPd8lEcwnmWYvw"/>
# ...

# %%
# !pip install html5lib

# %%
# !pip install bs4
#!pip install requests

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>World gold price</b></h3>
# <p> Buy: 2,659.8 USD/ounce</p>
# <p> Sell: 2,660.8 USD/ ounce</p>
# <h3> SJC gold price</h3>
# <p> Buy: 82.5 million VND/tael </p>
# <p> Sell: 84.5 million VND/tael </p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>World gold price</b></h3>
# <p> Buy: 2,659.8 USD/ounce</p>
# <p> Sell: 2,660.8 USD/ ounce</p>
# <h3> SJC gold price</h3>
# <p> Buy: 82.5 million VND/tael </p>
# <p> Sell: 84.5 million VND/tael </p>
# </body>
# </html>

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>World gold price</b></h3><p> Buy: 2,659.8 USD/ounce </p><p> Sell: 2,660.8 USD/ ounce</p><h3> SJC gold price</h3><p> Buy: 82.5 million VND/tael </p><p> Sell: 84.5 million VND/tael </p></body></html>"

# %%
tag_object=soup.title
print("tag object:",tag_object)
# Out:
# tag object: <title>Báo VnExpress - Báo tiếng Việt nhiều người xem nhất</title>

# %%
print("tag object type:",type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %%
tag_child =tag_object.b
tag_child

# %%
tag_object
# Out:
# <title>Báo VnExpress - Báo tiếng Việt nhiều người xem nhất</title>

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <meta content="VnExpress tin tức mới nhất - Thông tin nhanh &amp; chính xác được cập nhật hàng giờ. Đọc báo tin tức online Việt Nam &amp; Thế giới nóng nhất trong ngày về thể thao, thời sự, pháp luật, kinh doanh,..." name="description"/>

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# '\n'

# %%
sibling_2.next_sibling
# Out:
# <meta content="VnExpress, tin tức, tin the gioi, tin nhanh, tin tuc viet nam, doc bao" name="keywords"/>
